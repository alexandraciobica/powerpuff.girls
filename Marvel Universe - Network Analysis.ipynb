# %% [markdown]
# # <font color = "#018786"> Network analysis </font>

# %% [markdown]
# We will perform a network analysis on the network of  comic book characters from the Marvel Universe. We decided to focus on the first 10.000 characters, sorted from A to Z. For each character we collected their wikia page and which nationality they belong to (for community detection). This data was accessible by parsing the relevant web pages at http://marvel.wikia.com/wiki. Below, we will describe the different steps in our network analysis:

# %% [markdown]
# * 0\. Load Modules
# * 1\. Data Extraction
#     * 1.1\. Extract Characters
#     * 1.2\. Extract Nationalities
#     * 1.3\. Extract Links
#     * 1.4\. Data Merging
#     * 1.5\. Data Cleaning
# * 2\. Network Analysis
#     * 2.1\. Communities
#     * 2.2\. Network Visualization
#     * 2.3\. Degree Distribution
#     * 2.4\. Modularity
#     * 2.5\. Confusion Matrix

# %% [markdown]
# ## 0.  **Load Modules**

# %%
import json, operator, community #JSON parser, efficient operator functions, python-louvain package
from urllib2 import urlopen #extensible library for opening URLs
import urllib # package for working with URL's
from bs4 import BeautifulSoup #pulling data out from HTML and XML files
from prettytable import PrettyTable #displaying tabular data in a ASCII table format
import matplotlib.pyplot as plt # plotting figures
import numpy as np # powerful calculation library
import networkx as nx # networks creation library
from networkx.drawing.nx_agraph import graphviz_layout
import cPickle as pickle # python data structures as files
# %matplotlib inline
from fa2 import ForceAtlas2
from itertools import count

# %%
def prettifyName(name):
    name = name.replace('_',' ') if '_' in name else name
    return name

# %% [markdown]
# ## 1.  **Data Extraction**
# ### 1.1 Extract Characters
# With *getCharacters()* function, we retrieve 10 000 characters from the Marvel wikia page. For every character, we save his ID, nationality and set of all of their links in a dictionary.

# %%
def getCharacters():

    response = urlopen('http://marvel.wikia.com/api/v1/Articles/List?expand=1&category=Characters&limit=10000')
    html = response.read()
    j = json.loads(html)
    characters = dict()
    c = j.get("items")
    
    for a in c:
        name = (a.get("title")).replace(' ', '_')
        idName = (a.get("id"))
        characters[name] = {'id': idName, 'page' : set(), 'nationality' : "Alien"}
    
    return characters

# %%
characters = getCharacters()

# %%
len(characters)
# Out:
# 10000

# %% [markdown]
# ### 1.2 Extract Nationalities
# With *getNationalities()* function, we retrieve the nationalities from the Marvel wikia page. Save them in a list.

# %%
 def getNationalities():
    response = urlopen('http://marvel.wikia.com/api/v1/Articles/List?expand=1&category=Characters_by_Nationality&limit=10000')
    html = response.read()
    j = json.loads(html)
    c = j.get("items")

    nationalities = []
    for a in c:
        nationality = (a.get("title")).replace(' ', '_')
        nationalities.append(nationality)
    
    return nationalities

# %%
nationalities = getNationalities()

# %%
len(nationalities)
# Out:
# 333

# %% [markdown]
# ### 1.3 Data Merging
# With *getNationalitiesForCharacters()* function, we connect the origin information with the characters and update the dictionary with the new information.

# %%
def getNationalitiesForCharacters(characters, nationalities):
    for nationality in nationalities:
        try:
            #print("nationality is " + nationality)
            response = urlopen(r'http://marvel.wikia.com/api/v1/Articles/List?expand=1&category=%s&limit=10000' % nationality)
            html = response.read()
            chars = json.loads(html)
            c = chars.get("items")
            for a in c:
                try:
                    name = (a.get("title")).replace(' ', '_')
                    characters[name]['nationality'] = nationality
                except KeyError:
                    pass
        except:
            print("nationality got an http error" + nationality)      
    return characters

# %%
getNationalitiesForCharacters(characters, nationalities)
# Out:
# nationality got an http errorBagmoman
# nationality got an http errorBelizean
# nationality got an http errorCommorians
# nationality got an http errorKeshanis
# nationality got an http errorLatkovians
# nationality got an http errorMacedonian
# nationality got an http errorMeroë_citizens
# nationality got an http errorMonacoan
# nationality got an http errorNone
# nationality got an http errorNor-Am_Pact_region
# nationality got an http errorPuntians
# nationality got an http errorRudyardians
# nationality got an http errorSudanese
# nationality got an http errorYamatai
# nationality got an http errorZamboulan
# nationality got an http errorZenoshans
# {u'Alyssa_Moy_(Earth-616)': {'id': 19623,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Cessily_Kincaid_(Earth-600123)': {'id': 501558,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Andrea_Vecchiato_(Earth-1610)': {'id': 780294,
#   'nationality': u'Italians',
#   'page': set()},
#  u'Adelynn_Duquesne_(Earth-616)': {'id': 738533,
#   'nationality': u'French',
#   'page': set()},
#  u'Alexi_Alexivitch_(Earth-616)': {'id': 1113731,
#   'nationality': u'Soviets',
#   'page': set()},
#  u'Beltan_(Earth-616)': {'id': 1067447,
#   'nationality': u'Cimmerians',
#   'page': set()},
#  u'Belle_(A.I.)_(Earth-TRN659)': {'id': 1108390,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Abner_Jenkins_(Earth-TRN005)': {'id': 435584,
#   'nationality': u'Latverians',
#   'page': set()},
#  u'Alexander_Flynn_(Earth-616)': {'id': 30106,
#   'nationality': u'Latverians',
#   'page': set()},
#  u'Adele_Santiago_(Earth-616)': {'id': 872313,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Black_Widow_(Earth-61211)': {'id': 773233,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Amy_(Mutant)_(Earth-616)': {'id': 799980,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Chase_Stein_(Earth-2149)': {'id': 248074,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Benjamin_Grimm_(Earth-1815)': {'id': 166283,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Bruce_Banner_(Earth-904913)': {'id': 484494,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Benjamin_Jones_(Earth-712)': {'id': 15268,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Alexander_Walsh_(Earth-616)': {'id': 95182,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Anthony_Stark_(Earth-415)': {'id': 1040963,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Buck_Cashman_(Earth-616)': {'id': 1255,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Blackagar_Boltagon_(Earth-13017)': {'id': 839656,
#   'nationality': u'Attilans',
#   'page': set()},
#  u'Billy_Russo_(Earth-TRN416)': {'id': 1181043,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Amos_Lockhart_(Earth-616)': {'id': 1185272,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Bruce_Banner_(Earth-81122)': {'id': 412206,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Artie_Hames_(Earth-616)': {'id': 1036037,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Anthony_Stark_(Earth-9512)': {'id': 687348,
#   'nationality': u'Americans',
#   'page': set()},
#  u'A._Trabbold_(Earth-928)': {'id': 806081,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Achilles_(Earth-616)': {'id': 15382,
#   'nationality': u'Greeks',
#   'page': set()},
#  u'Ben_Reilly_(Earth-1610)': {'id': 311517,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Arthur_Douglas_(Earth-5631)': {'id': 740145,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Archangel_(Earth-2122)': {'id': 363260,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Arachne_(Demon-Fire)_(Earth-616)': {'id': 57032,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Burglar_(Earth-958)': {'id': 567780,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Atalon_(Earth-93060)': {'id': 59939, 'nationality': 'Alien', 'page': set()},
#  u'Biotron_II_(Earth-616)': {'id': 495129,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Aaron_Delgato_(Earth-928)': {'id': 575341,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Annihilata_(Earth-691)': {'id': 771767,
#   'nationality': u'Negative_Zoner',
#   'page': set()},
#  u'Anastasia_Sablinova_(Earth-TRN461)': {'id': 1071299,
#   'nationality': u'Symkarians',
#   'page': set()},
#  u'Brian_Grey_(Earth-616)': {'id': 400087,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Charles_Mitchell_(Earth-616)': {'id': 1133088,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Anya_Corazon_(Earth-TRN633)': {'id': 1070201,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Celeste_Cuckoo_(Earth-616)': {'id': 39972,
#   'nationality': u'Utopians',
#   'page': set()},
#  u'Agent_5_(Earth-616)': {'id': 97309, 'nationality': 'Alien', 'page': set()},
#  u'Afterlife_(Earth-616)': {'id': 18434,
#   'nationality': u'Heaven_citizens',
#   'page': set()},
#  u'Cameron_Klein_(Earth-199999)': {'id': 802400,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Bride_of_Frankenstein_(Earth-616)': {'id': 333395,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Benjamin_Savannah_(Earth-616)': {'id': 490922,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Bethany_Bellamy_(Earth-616)': {'id': 1135671,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Blecch_Bolt_(Earth-9047)': {'id': 554520,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Charles_Xavier_(Earth-32000)': {'id': 700353,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Burt_Kelso_(Earth-616)': {'id': 1199129,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Benjamin_Grimm_(Earth-9916)': {'id': 324839,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Ali_Wazoo_(Earth-616)': {'id': 18622,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Anton_Cartier_(Earth-616)': {'id': 1026161,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Baryn_(Earth-616)': {'id': 417501,
#   'nationality': u'Skrull_Imperials',
#   'page': set()},
#  u'Charlie_Jordon_(Earth-616)': {'id': 1134763,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Bentley_Wittman_(Earth-917)': {'id': 1004521,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Aron_(Earth-691)': {'id': 722446, 'nationality': 'Alien', 'page': set()},
#  u'Braxus_(Earth-616)': {'id': 129886, 'nationality': 'Alien', 'page': set()},
#  u'Baby_Face_Johnny_(Earth-51914)': {'id': 581775,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Cesium_(Element)_(Earth-616)': {'id': 424109,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Buzzkill_(Andrew)_(Earth-616)': {'id': 635657,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Adolf_Hitler_(Earth-7642)': {'id': 1155497,
#   'nationality': u'Germans',
#   'page': set()},
#  u'Alexander_Summers_(Earth-616)': {'id': 1802,
#   'nationality': u'Utopians',
#   'page': set()},
#  u'Albert_Frederick_Arthur_George_(Earth-616)': {'id': 1065899,
#   'nationality': u'British',
#   'page': set()},
#  u'Cain_Marko_(Earth-TRN064)': {'id': 670668,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Bruiser_(Earth-135263)': {'id': 688860,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Abel_(Earth-616)': {'id': 18394, 'nationality': 'Alien', 'page': set()},
#  u'Chai_Phen_(Earth-616)': {'id': 1079519,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Abbot_(Earth-88194)': {'id': 75934, 'nationality': 'Alien', 'page': set()},
#  u'Basher_(Earth-616)': {'id': 196073,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Ava_Ayala_(Earth-TRN012)': {'id': 944569,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Bruce_Banner_(Earth-91172)': {'id': 98366,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Buluku_(Earth-4321)': {'id': 47471, 'nationality': 'Alien', 'page': set()},
#  u'Ben_(Earth-13003)': {'id': 123863,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Brushnev_(Earth-616)': {'id': 516064,
#   'nationality': u'Russians',
#   'page': set()},
#  u'Airhead_(Earth-616)': {'id': 15657,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Andrew_Blanding_(Earth-616)': {'id': 427055,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Anna_Maria_Marconi_(A.I.)_(Earth-TRN588)': {'id': 751612,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Benjamin_Grimm_(Earth-8454)': {'id': 567500,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Chameleon_(Earth-9500)': {'id': 56833,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Carmen_Averez_(Earth-616)': {'id': 1186989,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Adjudicator_(Earth-71016)': {'id': 626634,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Abner_Jenkins_(Earth-64894)': {'id': 420858,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Carl_Larsen_(Earth-200111)': {'id': 1127405,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Brank_(Earth-20051)': {'id': 253283, 'nationality': 'Alien', 'page': set()},
#  u'Bruce_Banner_(Earth-31117)': {'id': 631493,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Cernunnos_(Earth-93060)': {'id': 309267,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Alflyse_(Earth-616)': {'id': 278880,
#   'nationality': u'Svartalfheim_citizens',
#   'page': set()},
#  u'Benjamin_Parker_(Earth-TRN581)': {'id': 957967,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Benjamin_Grimm_(Earth-79715)': {'id': 329088,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Blockade_(Earth-691)': {'id': 43752, 'nationality': 'Alien', 'page': set()},
#  u'Burll_(Earth-20051)': {'id': 744914, 'nationality': 'Alien', 'page': set()},
#  u'Barry_Huff_(Earth-TRN588)': {'id': 1068313,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Bear_(Jimmy)_(Earth-199999)': {'id': 897671,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Carl_Weathers_(Earth-616)': {'id': 849055,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Alexander_Power_(Earth-635972)': {'id': 464768,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Captain_Krause_Storm_(Earth-616)': {'id': 487381,
#   'nationality': u'Germans',
#   'page': set()},
#  u'Agamotto_(Earth-12041)': {'id': 1140673,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Bert_Rose_(Earth-616)': {'id': 721564,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Alain_Gris_(Earth-928)': {'id': 809135,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Baron_(Milehigh_Keep)_(Earth-616)': {'id': 962747,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Amy_Minoru_(Earth-199999)': {'id': 1130345,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Casey_Miller_(Earth-616)': {'id': 883354,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Agnar,_King_of_the_Eagles_(Earth-616)': {'id': 42792,
#   'nationality': u'Asgardians',
#   'page': set()},
#  u'Barbara_Morse_(Earth-8096)': {'id': 399322,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Black_Wolf_(Earth-616)': {'id': 1052006,
#   'nationality': u'Canadians',
#   'page': set()},
#  u'Alejandro_Gutierrez_(Earth-20051)': {'id': 744716,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Alonzo_Gonzales_(Earth-616)': {'id': 754512,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Captain_Dash_(Earth-1241)': {'id': 103186,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Caprice_Hastings_(Earth-616)': {'id': 1164609,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Billy_Glow_(Earth-616)': {'id': 709504,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Captain_Universe_(Earth-616)': {'id': 1292,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Bob_Garrett_(Earth-200111)': {'id': 1123255,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Antandr\xe8_(Earth-616)': {'id': 1040140,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Benjamin_Parker_(Earth-901220)': {'id': 915190,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Burron_(Earth-616)': {'id': 579247,
#   'nationality': u'Attilans',
#   'page': set()},
#  u'Alisande_Morales_(Earth-616)': {'id': 693420,
#   'nationality': u'Cubans',
#   'page': set()},
#  u'Ardina_(Earth-616)': {'id': 120220, 'nationality': 'Alien', 'page': set()},
#  u'Black_Widow_(Petra)_(Earth-616)': {'id': 697760,
#   'nationality': u'Soviets',
#   'page': set()},
#  u'8-Ball_(Hobgoblin)_(Earth-616)': {'id': 697616,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Blood_Brothers_(Earth-12041)': {'id': 671513,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Bruce_Baker_(Earth-616)': {'id': 1006389,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Callisto_(Earth-11326)': {'id': 433834,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Benedict_Kine_(Earth-616)': {'id': 16665,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Brock_Rumlow_(Earth-81223)': {'id': 720469,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Anthony_Stark_(Earth-947)': {'id': 317780,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Ahirom_(Earth-616)': {'id': 1053894,
#   'nationality': u'Halwanians',
#   'page': set()},
#  u'Ambush_the_Lunatik_(Earth-9602)': {'id': 754745,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Bruce_Banner_(Earth-18119)': {'id': 854357,
#   'nationality': u'Americans',
#   'page': set()},
#  u"Ch'vayre_(Earth-4935)": {'id': 30084,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Benjamin_Grimm_(Earth-8110)': {'id': 302435,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Charlie-27_(Earth-11891)': {'id': 285658,
#   'nationality': 'Alien',
#   'page': set()},
#  u'C.J._Miller_(Earth-616)': {'id': 454051,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Araki_(Earth-9112)': {'id': 352679,
#   'nationality': u"Shi'ar_Imperials",
#   'page': set()},
#  u"Ch'od_(Earth-92131)": {'id': 391124,
#   'nationality': u"Shi'ar_Imperials",
#   'page': set()},
#  u'Chris_Johnson_(Earth-730784)': {'id': 1154289,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Batragon_(Earth-616)': {'id': 165571,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Cancer_(LMD)_(Earth-616)': {'id': 1273,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Charles_Chewatt_(Earth-616)': {'id': 482818,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Amphibian_(Earth-31916)': {'id': 35287,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Black_Widow_(Tania)_(Earth-23291)': {'id': 861949,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Captain_Super_(Earth-9047)': {'id': 1050949,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Brakon_(Earth-42777)': {'id': 190131,
#   'nationality': u'Attilans',
#   'page': set()},
#  u'Bruce_Banner_(Earth-TRN362)': {'id': 693146,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Bubbles_(Earth-1007)': {'id': 671157,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Alicia_Masters_(Earth-89112)': {'id': 722463,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Barbie_(Earth-928)': {'id': 804155,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Charles_Ingwe_(Earth-616)': {'id': 1132196,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Alkinoos_(Microverse)_(Earth-7614)': {'id': 562989,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Carlos_Cruz_(Earth-TRN010)': {'id': 1123111,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Ciaran_McCoy_(Earth-41001)': {'id': 454728,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Baby_Face_Barker_(Earth-616)': {'id': 1006379,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Agent_Monkton_(Earth-616)': {'id': 703910,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Cardinal_(ICON)_(Earth-616)': {'id': 641120,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Andrew_Christensen_(Earth-33900)': {'id': 790066,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Bentley_Wittman_(Clone)_(Earth-15513)': {'id': 985857,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Alex_Wildman_(Earth-616)': {'id': 325564,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Bill_Brinkly_(Earth-616)': {'id': 872318,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Abu_Ho_Dadi_(Earth-616)': {'id': 18387,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Cameron_Hodge_(Earth-161)': {'id': 412665,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Alistaire_Smythe_(Earth-58163)': {'id': 124923,
#   'nationality': u'Americans',
#   'page': set()},
#  u"Christian_L'Argent_(Earth-928)": {'id': 802680,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Carol_Danvers_(Earth-9590)': {'id': 604154,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Blackbone_(Earth-616)': {'id': 1173378,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Adam_Blackveil_(Earth-616)': {'id': 584546,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Brother_Gregori_(Earth-616)': {'id': 998759,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Bottom_(Earth-928)': {'id': 798001, 'nationality': 'Alien', 'page': set()},
#  u'Ben_Urich_(Earth-91600)': {'id': 308991,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Carlos_Ramirez_(Earth-200111)': {'id': 1121236,
#   'nationality': u'Cubans',
#   'page': set()},
#  u'August_Wu_(Earth-616)': {'id': 912245,
#   'nationality': u'Chinese',
#   'page': set()},
#  u'Bella_(Dog)_(Earth-616)': {'id': 1187019,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Boneyard_(Earth-616)': {'id': 85041, 'nationality': 'Alien', 'page': set()},
#  u'Anthony_Stark_(Earth-20132)': {'id': 607637,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Anthony_Stark_(Earth-10041)': {'id': 996895,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Annihilus_(Earth-91111)': {'id': 349577,
#   'nationality': u'Negative_Zoner',
#   'page': set()},
#  u'Charles_Xavier_(M.O.D.O.K.)_(Earth-295)': {'id': 478164,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Ardat_(Earth-616)': {'id': 1089694, 'nationality': 'Alien', 'page': set()},
#  u'Arimanes_(Earth-616)': {'id': 387135,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Adrian_Toomes_(Earth-7642)': {'id': 1201655,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Aloysius_Thorndrake_(Earth-616)': {'id': 350434,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Charles_Brown_(Earth-616)': {'id': 1214901,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Chi_Chan_(Earth-616)': {'id': 1113719,
#   'nationality': u'Kakarantharaians',
#   'page': set()},
#  u'Ben_Reilly_(Earth-TRN409)': {'id': 757549,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Alison_Blaire_(Earth-11080)': {'id': 584013,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Anthony_Stark_(Earth-12)': {'id': 87039,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Carol_Danvers_(Earth-721)': {'id': 76172,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Carnage_(Doppelganger)_(Earth-TRN579)': {'id': 966596,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Charles_Baskerville_(Earth-616)': {'id': 1130770,
#   'nationality': u'British',
#   'page': set()},
#  u'Beatrice_de_la_Salle_(Earth-616)': {'id': 413793,
#   'nationality': u'Canadians',
#   'page': set()},
#  u'Aleksei_Sytsevich_(Earth-11131)': {'id': 1202364,
#   'nationality': u'Russians',
#   'page': set()},
#  u'3.14159_(Earth-1191)': {'id': 393811,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Charles_Xavier_(Earth-8107)': {'id': 285527,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Burke_(Earth-616)': {'id': 1257, 'nationality': 'Alien', 'page': set()},
#  u'Benjamin_Grimm_(Earth-989)': {'id': 569015,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Charles_Benton_(Earth-616)': {'id': 1112,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Aqwen_(Earth-616)': {'id': 566146, 'nationality': 'Alien', 'page': set()},
#  u'Anthony_Stark_(Earth-113500)': {'id': 502054,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Christina_Aguilar_(Earth-616)': {'id': 117212,
#   'nationality': u'Brazilians',
#   'page': set()},
#  u'Anthony_Stark_(Earth-TRN579)': {'id': 969775,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Bolivar_Trask_(Earth-11052)': {'id': 284755,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Carol_Harding_(Earth-616)': {'id': 716775,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Abd-el-Hazred_(Earth-616)': {'id': 34458,
#   'nationality': u'Saudi_Arabians',
#   'page': set()},
#  u'Beta_Ray_Bill_(Earth-9997)': {'id': 826335,
#   'nationality': u'Korbinites',
#   'page': set()},
#  u'Black_Fang_(Earth-616)': {'id': 1177826,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Bruce_Banner_(Earth-98)': {'id': 638344,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Ao_Jun_(Earth-616)': {'id': 16515,
#   'nationality': u'Chinese',
#   'page': set()},
#  u'Anticlus_(Earth-616)': {'id': 1040134,
#   'nationality': u'Greeks',
#   'page': set()},
#  u'Bux_(Earth-616)': {'id': 404735,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Carnage_(Klyntar)_(Earth-91119)': {'id': 994480,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Bob_Hardin_(Earth-93060)': {'id': 59843,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Annie_Stevenson_(Earth-148611)': {'id': 544894,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Benjamin_Parker_(Earth-70237)': {'id': 905905,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Ava_Ayala_(Earth-61610)': {'id': 927947,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Barry_Shapiro_(Earth-19828)': {'id': 851304,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Bloody_Mary_(Bacchae)_(Earth-616)': {'id': 971236,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Betty_Lou_Anderson_(Earth-616)': {'id': 885136,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Annalee_(Earth-616)': {'id': 3834,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Adolf_Hitler_(Earth-TRN564)': {'id': 903949,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Arnie_Berman_(Earth-616)': {'id': 657860,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Axel_Cluney_(Earth-TRN678)': {'id': 1158870,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Alexander_Power_(Earth-13266)': {'id': 1175630,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Amora_(Earth-12131)': {'id': 636832,
#   'nationality': u'Asgardians',
#   'page': set()},
#  u'Asahiri_Aoki_(Earth-616)': {'id': 531166,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Alim_Halladah_(Earth-616)': {'id': 26907,
#   'nationality': u'Trans-Sabalians',
#   'page': set()},
#  u'Azura_(Earth-89721)': {'id': 565139,
#   'nationality': u'Olympian_Eternals',
#   'page': set()},
#  u'Andy_Warthog_(Earth-8311)': {'id': 471186,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Abraham_Beame_(Earth-616)': {'id': 70947,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Ben_Grizzly_(Earth-94024)': {'id': 658482,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Amora_(Earth-730834)': {'id': 791976,
#   'nationality': u'Asgardians',
#   'page': set()},
#  u'Animator_(Earth-616)': {'id': 502447,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Anya_Corazon_(Earth-616)': {'id': 3763,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Annihilus_(Earth-TRN430)': {'id': 751810,
#   'nationality': u'Negative_Zoner',
#   'page': set()},
#  u'Angel_Dust_(Christina)_(Earth-TRN414)': {'id': 886254,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Bruce_Banner_(Earth-200527)': {'id': 593266,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Barbiel_(Earth-616)': {'id': 1094716,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Arcade_(Earth-6109)': {'id': 306379,
#   'nationality': u'Americans',
#   'page': set()},
#  u"Ch'od_(Earth-295)": {'id': 30562,
#   'nationality': u"Shi'ar_Imperials",
#   'page': set()},
#  u'Asinine_Torch_(Earth-8311)': {'id': 389604,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Charity_Brown_(Earth-616)': {'id': 1117940,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Boniface_(Earth-616)': {'id': 16275, 'nationality': 'Alien', 'page': set()},
#  u'9-Ball_(Earth-616)': {'id': 543477,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Cecilia_Reyes_(Earth-5700)': {'id': 473146,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Charles_Xavier_(Earth-81304)': {'id': 570176,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Boss_(Earth-616)': {'id': 524114,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Bessie_(Earth-13122)': {'id': 1117196,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Charlie_(Warzone)_(Earth-616)': {'id': 943205,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Aphrodite_Ourania_(Earth-616)': {'id': 11081,
#   'nationality': u'Olympus_citizens',
#   'page': set()},
#  u'America_Chavez_(Earth-13122)': {'id': 912785,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Brendon_Doyle_(Earth-199999)': {'id': 607216,
#   'nationality': u'British',
#   'page': set()},
#  u'Aaliyah_Hardin_(Earth-616)': {'id': 590413,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Aqualung_(Earth-148611)': {'id': 352368,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Ambrose_(Locust_King)_(Earth-616)': {'id': 970490,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Amadeus_Cho_(Earth-TRN562)': {'id': 1028620,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Chikeko_Tomomatsu_(Earth-616)': {'id': 666929,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Bull_(Earth-8311)': {'id': 841305, 'nationality': 'Alien', 'page': set()},
#  u'Bruce_Banner_(Home_Base_Clone)_(Earth-616)': {'id': 1132281,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Abdul_Qamar_(Earth-616)': {'id': 34221,
#   'nationality': u'Saudi_Arabians',
#   'page': set()},
#  u'Charles_Xavier_(Earth-TRN169)': {'id': 608791,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Cassandra_Lang_(Earth-12041)': {'id': 1053540,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Artemus_Pithins_(Earth-616)': {'id': 236685,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Avoe_(Earth-616)': {'id': 473720, 'nationality': 'Alien', 'page': set()},
#  u'Blackthorn_(Earth-616)': {'id': 16268,
#   'nationality': u"Shi'ar_Imperials",
#   'page': set()},
#  u'Blackagar_Boltagon_(Earth-90251)': {'id': 630432,
#   'nationality': u'Attilans',
#   'page': set()},
#  u'Bradley_Beemer_(Earth-616)': {'id': 21420,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Cain_Marko_(Earth-2988)': {'id': 623013,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Allanson_(Earth-616)': {'id': 922767,
#   'nationality': u'British',
#   'page': set()},
#  u'Burt_Corrigan_(Earth-616)': {'id': 255159,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Bentley_Wittman_(Earth-2149)': {'id': 247195,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Att-Lass_(Earth-2149)': {'id': 901839,
#   'nationality': u'Kree_Imperials',
#   'page': set()},
#  u'Adria_(Earth-616)': {'id': 18402, 'nationality': 'Alien', 'page': set()},
#  u'Bruce_Banner_(Earth-807128)': {'id': 281642,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Bulka_(Earth-5391)': {'id': 681607, 'nationality': 'Alien', 'page': set()},
#  u'Bernard_Bushkin_(Earth-80219)': {'id': 302287,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Alexander_Pierce_(Earth-1298)': {'id': 257074,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Canis_(Earth-982)': {'id': 558294, 'nationality': 'Alien', 'page': set()},
#  u'Annie_Richardson_(Earth-TRN686)': {'id': 1220145,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Angelica_Jones_(Clone)_(Earth-616)': {'id': 803607,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Adolf_Hitler_(Earth-597)': {'id': 584835,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Charles_Cotta_(Earth-616)': {'id': 591378,
#   'nationality': u'Romans',
#   'page': set()},
#  u'Angelo_Baldini_(Earth-616)': {'id': 1128,
#   'nationality': u'Italians',
#   'page': set()},
#  u'Aleta_Ogord_(Earth-9047)': {'id': 1079175,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Arthur_Norton_(Earth-616)': {'id': 707504,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Benjamin_Grimm_(Earth-89923)': {'id': 673998,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Cassandra_Nova_Xavier_(Earth-55133)': {'id': 861484,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Bolt_(Earth-9997)': {'id': 239928, 'nationality': 'Alien', 'page': set()},
#  u'Burglar_(Earth-95019)': {'id': 913198,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Buck_Banner_(Earth-807128)': {'id': 1191848,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Anthony_Stark_(Earth-93074)': {'id': 571523,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Cerberus_(Earth-616)': {'id': 1309,
#   'nationality': u'Olympus_citizens',
#   'page': set()},
#  u'Bruce_Banner_(Earth-TRN573)': {'id': 1206547,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Charles_Stockbridge_(Earth-616)': {'id': 1132955,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Bullseye_(Lester)_(Earth-82588)': {'id': 602878,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Alysande_Stuart_(Earth-9809)': {'id': 19652,
#   'nationality': u'Scottish',
#   'page': set()},
#  u'Adam_Warlock_(Earth-9997)': {'id': 40296,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Abu-Jamal_Rodriguez_(Earth-616)': {'id': 557491,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Christopher_Bradley_(Earth-616)': {'id': 3933,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Cindy_Moon_(Earth-TRN461)': {'id': 969465,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Armando_Mu\xf1oz_(Earth-98193)': {'id': 439418,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Chthon_(Earth-9997)': {'id': 828957, 'nationality': 'Alien', 'page': set()},
#  u'Chika_Tanaka_(Earth-101001)': {'id': 608663,
#   'nationality': u'Japanese',
#   'page': set()},
#  u'Badariel_(Earth-616)': {'id': 1094651,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Aahmes_(Earth-616)': {'id': 516692,
#   'nationality': u'Kushites',
#   'page': set()},
#  u'Banara_(Earth-616)': {'id': 288867,
#   'nationality': u'Atlanteans',
#   'page': set()},
#  u'Carter_Nichols_(Earth-9602)': {'id': 1081296,
#   'nationality': u'Canadians',
#   'page': set()},
#  u'Agent_Bradley_(Earth-616)': {'id': 1076125,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Anna-May_Parker_(Earth-18119)': {'id': 854138,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Blackagar_Boltagon_(Earth-2149)': {'id': 68490,
#   'nationality': u'Attilans',
#   'page': set()},
#  u'Angorr_(Earth-928)': {'id': 808565, 'nationality': 'Alien', 'page': set()},
#  u'Aldo_Zane_(Earth-616)': {'id': 706227,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Bryan_Cole_(Earth-616)': {'id': 432544,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Carver_(Morlock)_(Earth-616)': {'id': 16313,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Aleksei_Sytsevich_(Earth-2301)': {'id': 1170710,
#   'nationality': u'Russians',
#   'page': set()},
#  u'Brunnhilde_(Earth-TRN562)': {'id': 947437,
#   'nationality': u'Asgardians',
#   'page': set()},
#  u'Cheryl_Colon_(Earth-616)': {'id': 726267,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Chen_Lu_(Earth-TRN416)': {'id': 1181001,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Ben_Reilly_(Earth-12131)': {'id': 891080,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Chanda_(Earth-616)': {'id': 346194,
#   'nationality': u'Wakandans',
#   'page': set()},
#  u'Adrian_Toomes_(Earth-9922)': {'id': 467980,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Bloodmace_(Earth-928)': {'id': 432876,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Angelica_Jones_(Earth-16191)': {'id': 1174760,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Anthony_Stark_(Hulkbuster)_(Earth-TRN517)': {'id': 940645,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Aram-Set_(Earth-9997)': {'id': 833868,
#   'nationality': u'Egyptians',
#   'page': set()},
#  u'Awesome_Android_(Earth-92131)': {'id': 752738,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Charles_Xavier_(Earth-10330)': {'id': 321583,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Anthony_Stark_(Earth-12665)': {'id': 695540,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Aleksei_Sytsevich_(Earth-1048)': {'id': 1200945,
#   'nationality': u'Russians',
#   'page': set()},
#  u'Bruce_Banner_(Earth-8107)': {'id': 323213,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Charlie_(Wolf_Crew)_(Earth-72122)': {'id': 1135765,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Autumn_Rolfson_(Earth-1298)': {'id': 35766,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Angelica_Jones_(Earth-2988)': {'id': 689833,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Blind_Al_(Althea)_(Earth-11010)': {'id': 937435,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Allen_Marc_Yuric_(Earth-616)': {'id': 1331,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Alonzo_(Earth-616)': {'id': 824652, 'nationality': 'Alien', 'page': set()},
#  u'Benjamin_Parker_(Earth-TRN668)': {'id': 1139093,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Brubaker_(Astronaut)_(Earth-199999)': {'id': 1190000,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Broadside_(Crimson_Pirates)_(Earth-616)': {'id': 41981,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Alicia_Masters_(Earth-91119)': {'id': 576765,
#   'nationality': u'Americans',
#   'page': set()},
#  u'2-D_(Earth-616)': {'id': 90583, 'nationality': u'Americans', 'page': set()},
#  u'Andrew_Baxter_(Earth-616)': {'id': 1079908,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Carl_Burgess_(Earth-616)': {'id': 15508,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Cain_Marko_(Earth-89721)': {'id': 565137,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Bruce_Banner_(Earth-11418)': {'id': 593237,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Alexander_Nevsky_(Earth-616)': {'id': 1372,
#   'nationality': u'Soviets',
#   'page': set()},
#  u'Arrow_(Earth-616)': {'id': 564598,
#   'nationality': u'Americans',
#   'page': set()},
#  u"Avalanche_(Mesmero's_Brotherhood)_(Earth-616)": {'id': 1053461,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Black_Cloud_(Earth-616)': {'id': 1180839,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Blue_Kelso_(Earth-TRN375)': {'id': 778903,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Aaron_Nicholson_(Earth-TRN461)': {'id': 1134886,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Bolivar_Trask_(Homeland_Security)_(Earth-10005)': {'id': 99875,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Baal_(Gabriel)_(Earth-7642)': {'id': 1227962,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Bruce_Banner_(Earth-2713)': {'id': 570984,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Ahmed_(Tunnel_Rats)_(Earth-616)': {'id': 279957,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Alpha_Dog_(Earth-1610)': {'id': 167075,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Benjamin_Grimm_(Earth-4400)': {'id': 236201,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Bell_(U-Man)_(Earth-616)': {'id': 1005767,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Benjamin_Parker_(Earth-TRN579)': {'id': 975101,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Arkady_Rossovich_(Earth-TRN007)': {'id': 452905,
#   'nationality': u'Russians',
#   'page': set()},
#  u'Burgundy_(Earth-616)': {'id': 609946,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Charlie_(Serial_Killer)_(Earth-616)': {'id': 1135532,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Angelo_(Fixer)_(Earth-616)': {'id': 1120743,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Bart_Dongan_(Earth-616)': {'id': 1181613,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Apocryphus_(Earth-1952)': {'id': 15960,
#   'nationality': u'Olympian_Eternals',
#   'page': set()},
#  u'Brazen_(Earth-93060)': {'id': 403034,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Abraham_Cornelius_(Earth-10005)': {'id': 609079,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Charles_Olivetti_(Earth-616)': {'id': 1132639,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Carlie_Cooper_(Earth-616)': {'id': 107154,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Alexander_Summers_(Earth-13133)': {'id': 774082,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Anthony_Stark_(Earth-5631)': {'id': 736610,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Capricorn_(Ecliptic)_(Earth-616)': {'id': 116236,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Charles_J._Wentworth_(Earth-616)': {'id': 530091,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Ben_Morse_(Earth-616)': {'id': 716571,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Caliban_(Earth-905)': {'id': 483061,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Ava_Orlova_(Earth-616)': {'id': 837460,
#   'nationality': u'Ukrainians',
#   'page': set()},
#  u'Charles_Amundson_(Earth-616)': {'id': 86615,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Barbara_Petrovic_(Earth-15731)': {'id': 275815,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Charles_Buchanan_(Earth-616)': {'id': 527024,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Belial_(Demon)_(Earth-616)': {'id': 422266,
#   'nationality': u'Hell_citizens',
#   'page': set()},
#  u'Anastasia_Sablinova_(Earth-616)': {'id': 523511,
#   'nationality': u'Symkarians',
#   'page': set()},
#  u'Brian_Michael_Bendis_(Earth-1610)': {'id': 742388,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Caiera_(Earth-7121)': {'id': 549793, 'nationality': 'Alien', 'page': set()},
#  u'Christopher_Daniels_(Earth-616)': {'id': 108844,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Brie_Larmer_(Earth-616)': {'id': 683447,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Agent_R-2_(Earth-616)': {'id': 705609,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Archibald_Dyker_(Earth-616)': {'id': 1436,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Bruce_Banner_(Earth-7812)': {'id': 300416,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Arnold_Radisch_(Earth-616)': {'id': 968362,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Belathauzer_(Earth-616)': {'id': 1156,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Character_Template/Draft': {'id': 839211,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Amara_Aquilla_(Earth-616)': {'id': 10174,
#   'nationality': u'Utopians',
#   'page': set()},
#  u'Archer_Bryce_(Earth-616)': {'id': 638441,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Alfeo_Spinosa_(Earth-616)': {'id': 951336,
#   'nationality': u'Italians',
#   'page': set()},
#  u'Aalbort_(Earth-616)': {'id': 15357, 'nationality': 'Alien', 'page': set()},
#  u'Bonzo_(Earth-616)': {'id': 454142, 'nationality': 'Alien', 'page': set()},
#  u'Bloodthirst_(Earth-616)': {'id': 171429,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Aquarius_(Earth-101001)': {'id': 609504,
#   'nationality': u'Japanese',
#   'page': set()},
#  u'Alexei_Romanov_(Earth-616)': {'id': 893831,
#   'nationality': u'Soviets',
#   'page': set()},
#  u'Balder_Odinson_(Earth-841047)': {'id': 503843,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Arawn_(Earth-616)': {'id': 1120074, 'nationality': 'Alien', 'page': set()},
#  u'Burt_Collins_(Earth-616)': {'id': 1217206,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Buzz_Mason_(Earth-8107)': {'id': 284977,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Birthday_Bandit_(Earth-57780)': {'id': 660132,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Alexi_Rasputin_(Earth-9602)': {'id': 115962,
#   'nationality': u'Russians',
#   'page': set()},
#  u'Argon_(Microverse)_(Earth-616)': {'id': 386915,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Arthur_Parks_(Earth-534834)': {'id': 507768,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Brandon_Sharpe_(Earth-11511)': {'id': 451859,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Alflyse_(Earth-199999)': {'id': 666145,
#   'nationality': u'Svartalfheim_citizens',
#   'page': set()},
#  u'Charles_Xavier_(Earth-64894)': {'id': 654304,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Charlie_Cluster-7_(Earth-41001)': {'id': 468826,
#   'nationality': u'British',
#   'page': set()},
#  u'Bruce_Banner_(Earth-TRN589)': {'id': 966702,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Carrie_(Carefree)_(Earth-616)': {'id': 639778,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Benjamin_Grimm_(Earth-90266)': {'id': 655193,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Anthony_Stark_(Earth-829)': {'id': 286533,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Baron_Zemo_(Tsum_Tsum)_(Earth-616)': {'id': 1120191,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Brian_Calusky_(Earth-33629)': {'id': 480457,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Benjamin_Shalboub_(Heroes_Reborn)_(Earth-616)': {'id': 899013,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Blake_Schiel_(Earth-616)': {'id': 659023,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Benjamin_Grimm_(Earth-2189)': {'id': 236817,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Calvin_Rankin_(Earth-5700)': {'id': 467152,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Bethany_Palmer_(Earth-616)': {'id': 970338,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Alexander_Summers_(Earth-94040)': {'id': 481856,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Angelica_Neal_(Earth-616)': {'id': 155662,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Big_(Earth-616)': {'id': 244812, 'nationality': 'Alien', 'page': set()},
#  u'Benjamin_Grimm_(Earth-TRN583)': {'id': 762646,
#   'nationality': u'Americans',
#   'page': set()},
#  u'89P13_(Earth-91119)': {'id': 757669, 'nationality': 'Alien', 'page': set()},
#  u'Ben_Urich_(Earth-616)': {'id': 1161,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Cecilia_Cardinale_(Earth-616)': {'id': 5350,
#   'nationality': u'Cubans',
#   'page': set()},
#  u'Anthos_(Earth-691)': {'id': 688795, 'nationality': 'Alien', 'page': set()},
#  u'Anna_May_(Earth-18119)': {'id': 854281,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Antoine_Delsoin_(Earth-58163)': {'id': 101667,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Ancient_One_(Earth-92131)': {'id': 512166,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Bill_Rice_(Earth-616)': {'id': 884701,
#   'nationality': u'Canadians',
#   'page': set()},
#  u'Blaster_(Earth-691)': {'id': 18362, 'nationality': 'Alien', 'page': set()},
#  u'Angelo_Espinosa_(Earth-295)': {'id': 41012,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Ares_(Earth-5631)': {'id': 739601,
#   'nationality': u'Olympus_citizens',
#   'page': set()},
#  u'Benjamin_Grimm_(Earth-33900)': {'id': 439519,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Benjamin_Grimm_(Earth-TRN246)': {'id': 579279,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Artaud_Derrida_(Earth-616)': {'id': 728540,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Acid_Queen_(Earth-148611)': {'id': 557853,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Bullseye_(Lester)_(Earth-538)': {'id': 334829,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Aleksei_Sytsevich_(Earth-9411)': {'id': 984245,
#   'nationality': u'Russians',
#   'page': set()},
#  u'Brianna_Robbins_(Earth-616)': {'id': 418433,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Asha_(Yazata)_(Earth-616)': {'id': 1044448,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Anton_Mogart_(Earth-616)': {'id': 2704,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Agent_Shade_(Earth-199999)': {'id': 715089,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Aristis_(Earth-616)': {'id': 387143, 'nationality': 'Alien', 'page': set()},
#  u'Beverly_Cross_(Earth-616)': {'id': 439912,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Battle-Lon_(Earth-616)': {'id': 722086,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Agent_Anesthesia_(Earth-616)': {'id': 402988,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Bambi_(Earth-616)': {'id': 59411, 'nationality': 'Alien', 'page': set()},
#  u'Case_(Earth-928)': {'id': 804774,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Anthony_Stark_(Earth-1237)': {'id': 570995,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Charles_Xavier_(Earth-91119)': {'id': 481063,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Abu_Bakaar_(Earth-199999)': {'id': 117570,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Brian_Michael_Bendis_(Earth-40081)': {'id': 480789,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Aleksei_Sytsevich_(Earth-TRN006)': {'id': 442722,
#   'nationality': u'Russians',
#   'page': set()},
#  u'Alex_Grimond_(Earth-616)': {'id': 116886,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Apache_(Earth-616)': {'id': 644665, 'nationality': 'Alien', 'page': set()},
#  u'Aleksei_Sytsevich_(Earth-TRN576)': {'id': 1011601,
#   'nationality': u'Russians',
#   'page': set()},
#  u'Ajonga_(Earth-616)': {'id': 1206725,
#   'nationality': u'Southern_Isles_denizens',
#   'page': set()},
#  u'Baby_Thompson_(Earth-616)': {'id': 79644,
#   'nationality': u'Canadians',
#   'page': set()},
#  u'Ayla_Prentiss_(Earth-616)': {'id': 511955,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Benjamin_Grimm_(Earth-7187)': {'id': 640533,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Christopher_Powell_(Earth-112001)': {'id': 56048,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Cassandra_Lang_(Earth-11051)': {'id': 442095,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Brandon_Cross_(Earth-TRN483)': {'id': 847949,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Benjamin_Parker_(Earth-120703)': {'id': 532963,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Carl_Kaxton_(Earth-616)': {'id': 514322,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Anabolicus_(Earth-616)': {'id': 731335,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Bill_Stanton_(Earth-616)': {'id': 968799,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Achmar_(Earth-616)': {'id': 1065583,
#   'nationality': u'Corinthians',
#   'page': set()},
#  u'Beyonder_(Earth-8101)': {'id': 725605,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Baby_Peter_(Earth-13003)': {'id': 123859,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Ben_Grizzly_(Earth-8311)': {'id': 422549,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Annie_Lanning_(Earth-616)': {'id': 1075840,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Adrian_Toomes_(Earth-20051)': {'id': 701850,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Buckminster_Fuller_(Earth-616)': {'id': 542054,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Bison_(Warpies)_(Earth-616)': {'id': 69753,
#   'nationality': u'British',
#   'page': set()},
#  u'Bonegrinder_(Earth-616)': {'id': 489520,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Brian_DeWolff_(Earth-616)': {'id': 2013,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Arthur_Schweibe_(Earth-616)': {'id': 881503,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Amon_(Horse)_(Earth-616)': {'id': 386951,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Ben_Allardine_(Earth-616)': {'id': 994708,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Chtty_(Earth-616)': {'id': 1101875, 'nationality': 'Alien', 'page': set()},
#  u'Charles_Devonshire_(Earth-616)': {'id': 1133207,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Cassandra_Lang_(Earth-9047)': {'id': 1052526,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Al_(Alien)_(Earth-616)': {'id': 1033574,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Bruce_Banner_(Old_West)_(Earth-13122)': {'id': 1183796,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Bradley_Barrel_(Earth-616)': {'id': 1200662,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Admiral_(Xandarian)_(Earth-616)': {'id': 691043,
#   'nationality': u'Xandarians',
#   'page': set()},
#  u'Anthony_Stark_(Earth-61422)': {'id': 779552,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Cathy_Webster_(Earth-616)': {'id': 1663,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Bobo_(Earth-8311)': {'id': 1055182, 'nationality': 'Alien', 'page': set()},
#  u'Charles_Xavier_(Earth-9922)': {'id': 467908,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Bi-Beast_(Earth-8096)': {'id': 399297,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Brodar_(Earth-616)': {'id': 288875,
#   'nationality': u'Atlanteans',
#   'page': set()},
#  u'Cary_St._Lawrence_(Earth-9828)': {'id': 628972,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Benjamin_Grimm_(Earth-TRN417)': {'id': 736897,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Benjamin_Parker_(Earth-70105)': {'id': 197014,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Alison_Blaire_(Earth-652975)': {'id': 234545,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Amora_(Earth-616)': {'id': 1514,
#   'nationality': u'Asgardians',
#   'page': set()},
#  u'Charlie_Griffin_(Earth-616)': {'id': 1179815,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Bogat_(Earth-616)': {'id': 452707, 'nationality': 'Alien', 'page': set()},
#  u'Anthony_Shaw_(Earth-1191)': {'id': 101541,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Aristus_(Earth-616)': {'id': 1192947,
#   'nationality': u'Argosseans_(Hyborians)',
#   'page': set()},
#  u'Andrew_Jackson_Hawk_(Earth-81426)': {'id': 842997,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Black_Marvel_(Demon)_(Earth-616)': {'id': 1122002,
#   'nationality': 'Alien',
#   'page': set()},
# ...
#  u'Albert_of_Habsburg_(Earth-616)': {'id': 1054213,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Baltag_(Earth-6311)': {'id': 906483, 'nationality': 'Alien', 'page': set()},
#  u'Ayna_Sareva_(Earth-616)': {'id': 557395,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Casiolena_(Earth-616)': {'id': 46749,
#   'nationality': u'Asgardians',
#   'page': set()},
#  u'Ariana_(Earth-616)': {'id': 740623,
#   'nationality': u'Russians',
#   'page': set()},
#  u'Adrian_Toomes_(Earth-12610)': {'id': 893551,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Calvin_Falconer_(Earth-616)': {'id': 939074,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Chao_Sima_(Earth-616)': {'id': 50610,
#   'nationality': u'Chinese',
#   'page': set()},
#  u'Aquaria_Neptunia_(Earth-616)': {'id': 39133,
#   'nationality': u'Atlanteans',
#   'page': set()},
#  u'Bakra_(Earth-616)': {'id': 1122410,
#   'nationality': u'Turanians',
#   'page': set()},
#  u'Chuckles_(Bamf)_(Earth-616)': {'id': 1089529,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Anthony_Stark_(Earth-3290)': {'id': 334954,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Ben_Dewey_(Earth-20051)': {'id': 746323,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Aleta_Ogord_(Earth-691)': {'id': 37583,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Anthony_Stark_(Earth-523002)': {'id': 301534,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Baku_(Earth-791)': {'id': 1039582, 'nationality': 'Alien', 'page': set()},
#  u'Carl_Wilkinson_(Earth-616)': {'id': 98512,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Caspar_Wright_(Earth-616)': {'id': 441451,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Burglar_(Earth-92131)': {'id': 506930,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Brian_King_(Earth-616)': {'id': 743361,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Bloodcrow_(Earth-9602)': {'id': 765315,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Bomb_(Anthony)_(Earth-616)': {'id': 552575,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Adam_Cross_(Earth-199999)': {'id': 1200765,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Amy_Chen_(Child)_(Earth-616)': {'id': 795262,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Aragorn_(Earth-12131)': {'id': 624251,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Chad_Barrow_(Earth-616)': {'id': 416111,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Beta_Ray_Bill_(Earth-10022)': {'id': 509934,
#   'nationality': u'Korbinites',
#   'page': set()},
#  u'Alexander_Summers_(Earth-9112)': {'id': 567240,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Bread_(Earth-9047)': {'id': 1055768, 'nationality': 'Alien', 'page': set()},
#  u'Captain_Nokuru_(Earth-616)': {'id': 480237,
#   'nationality': u'Japanese',
#   'page': set()},
#  u'Anthony_Stark_(Earth-5692)': {'id': 85871,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Addison_Falk_(Earth-616)': {'id': 16455,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Alison_Blaire_(Earth-1610)': {'id': 34785,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Alvin_Arnold_(Earth-20051)': {'id': 742164,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Blackie_Malkin_(Earth-616)': {'id': 535638,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Charlie_Chicago_(Earth-616)': {'id': 1134925,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Bruce_Banner_(Earth-9289)': {'id': 1160247,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Bugman_(Earth-616)': {'id': 242198,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Al_Buchanan_(Earth-80521)': {'id': 157480,
#   'nationality': 'Alien',
#   'page': set()},
#  u'89P13_(Earth-TRN012)': {'id': 928770,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Akihiro_(Earth-6091)': {'id': 572832,
#   'nationality': u'Japanese',
#   'page': set()},
#  u'Captain_(Nextwave)_(Earth-7112)': {'id': 1110281,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Ana_Shwartz_(Earth-616)': {'id': 280721,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Bruce_Banner_(Earth-538)': {'id': 334861,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Cindy_Hingle_(Earth-982)': {'id': 773458,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Charles_Delazny_Jr._(Earth-616)': {'id': 1516,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Benjamin_Parker_(Earth-90214)': {'id': 323671,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Bambi_Long_(Earth-616)': {'id': 938613,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Alvin_Bernard_Harper_(Earth-616)': {'id': 609728,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Aragorn_(Earth-34882)': {'id': 844023,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Cheshire_(Earth-616)': {'id': 396073,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Cecelia_Monroe_(Earth-616)': {'id': 1024090,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Cassandra_Nova_Xavier_(Earth-92131)': {'id': 1034904,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Aleksei_Sytsevich_(Earth-89721)': {'id': 565135,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Anthony_Stark_(Earth-85826)': {'id': 998602,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Barton_Burdock_(Earth-9204)': {'id': 259162,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Blaquesmith_(Earth-4935)': {'id': 1206,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Carnage_(Klyntar)_(Earth-33734)': {'id': 624244,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Andrea_Byrne_(Earth-616)': {'id': 1035090,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Barbara_Morse_(Earth-61112)': {'id': 751161,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Basque_(Earth-616)': {'id': 418007, 'nationality': 'Alien', 'page': set()},
#  u'Carol_Danvers_(Earth-9602)': {'id': 124828,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Bruce_Banner_(Earth-TRN550)': {'id': 804635,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Anthony_Stark_(Earth-20110)': {'id': 419883,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Beyonder_(Earth-92131)': {'id': 506929,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Charles_Xavier_(Earth-40081)': {'id': 439091,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Bwana_Gambo_(Earth-616)': {'id': 448863,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Abraham_Klein_(Earth-904913)': {'id': 277756,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Alice_Parker_(Earth-616)': {'id': 1120435,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Blue_(Earth-811)': {'id': 330058, 'nationality': 'Alien', 'page': set()},
#  u'Celeste_Cuckoo_(Earth-55133)': {'id': 962211,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Charlie_Bash_(Earth-616)': {'id': 952128,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Chris_Kong_(Earth-616)': {'id': 1154281,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Baron_Togi_(Earth-616)': {'id': 492458,
#   'nationality': u'Japanese',
#   'page': set()},
#  u'Anthony_Stark_(Earth-TRN591)': {'id': 966982,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Agent_5_(Earth-8181)': {'id': 97310, 'nationality': 'Alien', 'page': set()},
#  u'Charles_Barton_(Earth-904913)': {'id': 760853,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Belladonna_(Microverse)_(Earth-616)': {'id': 422510,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Boss_Sapro_(Earth-616)': {'id': 441224,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Attuma_(Earth-71166)': {'id': 444060,
#   'nationality': u'Atlanteans',
#   'page': set()},
#  u'Bernie_Dillon_(Earth-616)': {'id': 35501,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Baron_Schluss_(Earth-616)': {'id': 494193,
#   'nationality': u'Germans',
#   'page': set()},
#  u'Balder_Odinson_(Earth-10190)': {'id': 259667,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Alice_Hayes_(Earth-616)': {'id': 177572,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Aarkus_(Earth-616)': {'id': 5557,
#   'nationality': u'Smokeworlders',
#   'page': set()},
#  u'Bruce_Banner_(Earth-4321)': {'id': 391823,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Alison_Double_(Earth-616)': {'id': 14062,
#   'nationality': u'British',
#   'page': set()},
#  u'Bass_(Hellbent)_(Earth-616)': {'id': 418011,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Bennet_du_Paris_(Earth-616)': {'id': 1530,
#   'nationality': u'French',
#   'page': set()},
#  u'Aaron_James_(Earth-199999)': {'id': 1088015,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Cadet_Randall_(Earth-616)': {'id': 881248,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Assemble_(Earth-1610)': {'id': 313756,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Beverly_Strange_(Earth-616)': {'id': 408872,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Alton_Vibereaux_(Earth-616)': {'id': 18184,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Bonesaw_McGraw_(Earth-11714)': {'id': 917554,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Christopher_Anderson_(Earth-21993)': {'id': 353322,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Annabelle_St._John_(Earth-616)': {'id': 1109412,
#   'nationality': u'Americans',
#   'page': set()},
#  u"C'vrrrk_Bludskuul_(Earth-13729)": {'id': 672132,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Barton_Blaze_(Earth-121347)': {'id': 609206,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Ashley_G._Williams_(Earth-2149)': {'id': 63304,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Benjamin_Parker_(Earth-TRN207)': {'id': 677068,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Cheryl_Swanson_(Earth-616)': {'id': 1220815,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Adrian_Toomes_(Earth-TRN009)': {'id': 443292,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Carhawk_(Earth-9047)': {'id': 1079221,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Blind_Charlie_(Earth-616)': {'id': 1134988,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Agent_Henderson_(Earth-616)': {'id': 1050499,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Amanda_Sheridan_(Earth-616)': {'id': 1076133,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Benjamin_Grimm_(Earth-8222)': {'id': 641086,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Benjamin_Grimm_(Earth-958)': {'id': 567772,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Alani_Ryan_(Earth-11069)': {'id': 501473,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Behinder_(Earth-9047)': {'id': 504447,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Alyssa_(Murdock)_(Earth-616)': {'id': 757970,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Al_Milgrom_(Earth-19828)': {'id': 851641,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Bruce_Banner_(Earth-534834)': {'id': 316655,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Chet_Huntley_(Earth-616)': {'id': 529204,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Big_Mother_(Earth-616)': {'id': 12233,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Carol_Danvers_(Earth-45017)': {'id': 743565,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Chief_Baxter_(Earth-616)': {'id': 1079885,
#   'nationality': u'British',
#   'page': set()},
#  u'Bruce_Bane_(Earth-9047)': {'id': 593073,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Adrian_Toomes_(Earth-TRN566)': {'id': 1086074,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Cain_Marko_(Earth-TRN169)': {'id': 682061,
#   'nationality': u'Americans',
#   'page': set()},
#  u"Cal'syee_Neramani_(Earth-295)": {'id': 30561,
#   'nationality': u"Shi'ar_Imperials",
#   'page': set()},
#  u'Annie_Deacons_(Earth-616)': {'id': 875236,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Benedict_Ryan_(Earth-616)': {'id': 476641,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Arkady_Rossovich_(Earth-11080)': {'id': 436006,
#   'nationality': u'Russians',
#   'page': set()},
#  u'Carlos_Lobo_(Earth-616)': {'id': 6152,
#   'nationality': u'Mexicans',
#   'page': set()},
#  u'Chen_Lu_(Earth-21261)': {'id': 1044132,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Arus_(Nemedian_Priest)_(Earth-616)': {'id': 632330,
#   'nationality': u'Nemedians',
#   'page': set()},
#  u'Annihilus_(Earth-13266)': {'id': 1175582,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Agent_Cohen_(Earth-616)': {'id': 881302,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Ben_Reilly_(Earth-91101)': {'id': 328474,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Cal_Johnson_(Earth-616)': {'id': 1053226,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Aries_(LMD)_(Earth-616)': {'id': 27841,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Calvin_Zabo_(Earth-807128)': {'id': 256864,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Chan_Liuchow_(Earth-616)': {'id': 274251,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Bharri_Zhan_(Earth-616)': {'id': 1169356,
#   'nationality': u'Shemites',
#   'page': set()},
#  u'Blackagar_Boltagon_(Earth-8545)': {'id': 188982,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Angela_Yin_(Earth-616)': {'id': 30322,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Chiun_(Earth-616)': {'id': 1205285, 'nationality': 'Alien', 'page': set()},
#  u'Cartier_St._Croix_(Earth-616)': {'id': 455453,
#   'nationality': u'Monacoans',
#   'page': set()},
#  u'Carol_Danvers_(Earth-3515)': {'id': 293097,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Angel_(Earth-TRN414)': {'id': 916710,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Alexander_Summers_(Earth-10005)': {'id': 420373,
#   'nationality': u'Americans',
#   'page': set()},
#  u"Canasta's_mom_(Earth-9047)": {'id': 731326,
#   'nationality': u'Japanese',
#   'page': set()},
#  u'Aubrey_Fawkes_(Earth-10091)': {'id': 634620,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Astarte_(Earth-616)': {'id': 16230, 'nationality': 'Alien', 'page': set()},
#  u'Benedict_(Earth-121347)': {'id': 609203,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Ajay_Roy_(Earth-616)': {'id': 807378,
#   'nationality': u'Indians',
#   'page': set()},
#  u'Billy_Russo_(Earth-12101)': {'id': 669096,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Binder_(Earth-616)': {'id': 262300,
#   'nationality': u"Shi'ar_Imperials",
#   'page': set()},
#  u'Brunnhilde_(Earth-61112)': {'id': 689508,
#   'nationality': u'Asgardians',
#   'page': set()},
#  u'Bruce_Banner_(Earth-200523)': {'id': 593265,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Charlie_Weaver_(Earth-616)': {'id': 1139595,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Bambina_Arbogast_(Earth-199999)': {'id': 609940,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Brian_Geparhart_(Earth-199999)': {'id': 1123742,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Ben_Urich_(Earth-TRN258)': {'id': 1003083,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Charles_Wilkes_(Earth-616)': {'id': 1084806,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Brian_Xavier_(Earth-616)': {'id': 18582,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Black_Suit_Spider-Man_(Tsum_Tsum)_(Earth-616)': {'id': 1120189,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Allmour_(Earth-616)': {'id': 1173375,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Armando_Aviles_(Earth-616)': {'id': 387377,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Adrian_Toomes_(Doppelganger)_(Earth-TRN579)': {'id': 966930,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Biggs_(Earth-616)': {'id': 851533, 'nationality': 'Alien', 'page': set()},
#  u'Boris_Bullski_(Earth-4400)': {'id': 236246,
#   'nationality': u'Russians',
#   'page': set()},
#  u'Blackagar_Boltagon_(Skrull)_(Earth-616)': {'id': 122157,
#   'nationality': u'Skrull_Imperials',
#   'page': set()},
#  u'Charlie_Clavven_(Earth-616)': {'id': 1138497,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Artabazus_(Earth-616)': {'id': 388593,
#   'nationality': 'Alien',
#   'page': set()},
#  u'Benjamin_Spock_(Earth-85101)': {'id': 1048371,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Benjamin_Hochberg_(Earth-616)': {'id': 870785,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Charles_Hinton_(Earth-199999)': {'id': 903109,
#   'nationality': u'Americans',
#   'page': set()},
#  u'Barack_Obama_II_(Earth-TRN391)': {'id': 838022,
#   'nationality': u'Americans',
#   'page': set()},
#  ...}

# %% [markdown]
# With *getNations()* function, we retrieve all nationalities in the Marvel universe, with *minCount* members.

# %%
def getNations(minCount=0):
    nations = dict()
    for k,v in characters.iteritems():
        n = v['nationality']
        if n != None:
            if n in nations:
                nations[n]['count'] += 1
                nations[n]['members'].append(k)
            else:
                nations[n] = dict()
                nations[n]['count'] = 1
                nations[n]['members'] = list()
                nations[n]['members'].append(k)
    nations = {k: v for k,v in nations.iteritems() if v['count'] > minCount}
    return nations

# %%
nations = getNations()

# %%
len(nations)
# Out:
# 187

# %% [markdown]
# ### 1.4 Extract Links
# With *getLinks()* function, we retrieve all links from the web page of a character, and update the characters dictionary with the new information.

# %%
def getLinks(characters):
    baseUrl = 'http://marvel.wikia.com/wiki/'
    for char,v in characters.iteritems():
        url = baseUrl + char
        try:
            response = urlopen(url.encode("utf-8"))
            source = response.read()
    
            soup = BeautifulSoup(source)
            div = soup.find(id="mw-content-text")
            ps = div.findChildren('p')
            for p in ps:
                hr = p.findChildren('a')
                if p.parent.name != 'td':
                    for h in hr:
                        if h.has_attr('href'):
                            if h['href'].startswith('/wiki'):
                                ele = h['href'].split('/')[-1:][0]
                                if '?' not in ele and 'Category' not in ele and not ele.startswith('File'):
                                    ele = ele.decode('unicode_escape').encode('ascii','ignore')
                                    v['page'].add(u''+ele) 
        except:
            pass
    return characters

# %%
characters = getLinks(characters)

# %%
#check how many empty sets we have #This is just testing
emptySets = 0
for key, value in characters.items():
    if len(value['page']) == 0:
        emptySets =emptySets + 1
print emptySets

# %% [markdown]
# ### 1.5 Data Cleaning
# We remove all characters with special symbols.

# %%
#Gives an error when we restart this function, without cleaning the characters dict          
for v in characters.values():
    for l in v['page']:
        if "%27" or "%C3%" in l:
            v['page'].remove(l)
            n = urllib.unquote(l)
            v['page'].add(n)
        elif "\xc3" or "\xe8" in l:
            l.encode("utf-8")

# %% [markdown]
# ## 2.  **Data Extraction**
# ### 2.1 Communities
# With *printNationsInfo()* function, we print how many communities have been found and how many charachers do they include.

# %%
def printNationsInfo(nations):
    sorted_nations = sorted(nations.items(), key=operator.itemgetter(1), reverse=True)
    nation_table = PrettyTable(['Nationality', 'Number of characters'])
    for n in sorted_nations:
        nation_table.add_row([n[0], n[1]['count']])
    return nation_table

# %%
print printNationsInfo(nations)

# %% [markdown]
# ### 2.2 Network Visualization

# %% [markdown]
#  - Create a directed graph over the characters and their links.

# %%
G = nx.DiGraph()
G.add_nodes_from(characters.keys())

# %%
len(G.nodes)

# %%
for k,v in characters.iteritems():
    for name in characters.keys():
        if (name in v['page'] and name !=k):
            G.add_edge(k, name)

# %%
len(G.edges)

# %% [markdown]
#  - Remove all of the isolated Nodes

# %%
isolatedNodes = nx.isolates(G)
G.remove_nodes_from(list(isolatedNodes))

# %%
len(G.nodes)

# %%
plt.figure(1,figsize=(12,12))
pos = nx.spring_layout(G)
nx.draw(G, node_size=30, node_color="#FF0000", node_shape='o', edge_color='.25', with_labels=False, width=.5, pos=pos)
plt.title('Full Marvel network')
plt.show()

# %% [markdown]
#  - Convert to undirected graph

# %%
U = G.to_undirected()

# %%
forceatlas2 = ForceAtlas2(
                          # Behavior alternatives
                          outboundAttractionDistribution=False,  # Dissuade hubs
                          edgeWeightInfluence=0.4,

                          # Performance
                          jitterTolerance=0.2,  # Tolerance
                          barnesHutOptimize=True,
                          barnesHutTheta=0.2,

                          # Tuning
                          scalingRatio=1.0,
                          strongGravityMode=False,
                          gravity=0.1,

                          # Log
                          verbose=True
)
    
positions = forceatlas2.forceatlas2_networkx_layout(U,pos=None, iterations=1000)
#enlarge plot
plt.figure(1, figsize=(12,12))
nx.draw(U, positions, width = 0.2, node_size=5, with_labels=False)
plt.title('Full Marvel network')
plt.axis('off')
plt.show()

# %%
G_wcc = max(nx.weakly_connected_component_subgraphs(G),key=len)

# %%
plt.figure(2,figsize=(12,12))
pos = nx.layout.fruchterman_reingold_layout(G_wcc)
nx.draw(G_wcc, node_size=30, node_color="#FF0000", node_shape='o', edge_color='.25', with_labels=False, width=.5, pos=pos)
plt.title('The largest component in the Marvel network')
plt.show()

# %% [markdown]
# ### 2.3 Degree Distribution
#  - With *printGraphStats()* we print some statistics of the graph such as degree, betweenness centrality and eigenvector centrality.

# %%
def printGraphStats(G_wcc, top=10):
    sorted_G_out_deg = sorted(G_wcc.out_degree(), key=operator.itemgetter(1), reverse=True)
    sorted_G_in_deg = sorted(G_wcc.in_degree(), key=operator.itemgetter(1), reverse=True)
    deg_table = PrettyTable(['Character - In degree',' Character - Out degree'])
    
    for i in range(top):
        a = ["%s, %d" % (prettifyName(sorted_G_in_deg[i][0]), sorted_G_in_deg[i][1]),
            "%s, %d" % (prettifyName(sorted_G_out_deg[i][0]), sorted_G_out_deg[i][1])]
        deg_table.add_row(a)
    
    G_bc = nx.betweenness_centrality(G_wcc)
    G_bc_sorted = [(k, G_bc[k]) for k in sorted(G_bc, key=G_bc.get, reverse=True)]

    bc_table = PrettyTable(['Character', 'Betweenness centrality'])
   
    for i in range(top):
        a = [prettifyName(G_bc_sorted[i][0]),
            "%.3f" % G_bc_sorted[i][1]]
        bc_table.add_row(a)

    ec_table = PrettyTable(['Character', 'Eigenvector centrality (In-degree)', 'Eigenvector centrality (Out-degree)'])
    G_ec_in = nx.eigenvector_centrality(G_wcc)
    G_ec_out = nx.eigenvector_centrality(G_wcc.reverse())
    G_ec_in_sorted = [(k, G_ec_in[k]) for k in sorted(G_ec_in, key=G_ec_in.get, reverse=True)]
    G_ec_out_sorted = [(k, G_ec_out[k]) for k in sorted(G_ec_out, key=G_ec_out.get, reverse=True)]    
    
    
    for i in range(top):
        a = [prettifyName(G_ec_in_sorted[i][0]), 
             "%.4f" % G_ec_in_sorted[i][1],
            "%.4f" % G_ec_out_sorted[i][1]
            ]
        ec_table.add_row(a)
    return deg_table, bc_table, ec_table

# %% [markdown]
#  - We display Top 5 charachers with highest **In Degree and Out Degree**

# %% [markdown]
# * **In Degree**
#  * Anthony Stark - Iron man
#  * Bruce Banner - Hulk
#  * Benjamin Grimm - The Thing from Fantastic 4
#  * Charles Xavier - Professor X
#  * Carol Danvers - Captain Marvel

# %% [markdown]
# * **Out Degree**
#  * Bruce Banner - Hulk
#  * Charles Xavier - Professor X
#  * Anthony Stark - Iron man
#  * Alison Blaire - Dazzler
#  * Alexander Summers - Havok

# %%
top = 5
deg_table, bc_table, ec_table = printGraphStats(G_wcc, top=top)
print "The top %d Marvel characters with highest In and Out degree" %top
print deg_table

# %% [markdown]
# - We display Top 5 charachers with highest **Betweenness Centrality**
#  * Bruce Banner - Hulk
#  * Anthony Stark - Iron man
#  * Charles Xavier - Professor X
#  * Alison Blaire - Dazzler
#  * Ares - Ares, God of war

# %%
print "\nThe top %d Marvel characters with highest Betweenness Centrality:" % top   
print bc_table

# %% [markdown]
# - We display Top 5 charachers with highest **Eigenvector centrality (In and Out degree)**
#  * Bruce Banner - Hulk
#  * Charles Xavier - Professor X
#  * Carol Danvers - Captain Marvel
#  * Anthony Stark - Iron man
#  * Alison Blaire - Dazzler

# %%
print "\nThe top %d Marvel characters with highest Eigenvector centrality (In and Out degree)" % top
print ec_table

# %% [markdown]
# ### 2.4 Modularity
# $$M=\sum\limits_{c=1}^{n_c}\left[\frac{L_c}{L}-\left(\frac{k_c}{2L}\right)^2 \right]$$
#
# $n_c$: Number of communities
# $L_c$: The total number of links within the community $C_c$
# $k_c$: The total degree of the nodes in the community $C_c$
# A node's *total degree*, $k_i$ is given by: $k_i=k_i^{in}+k_i^{out}$

# %%
def calculateModularity(nations):
    n_c = len(nations)
    m1 = 0; L1 = 0; k1 = 0; L = 0
    for nation, v in nations.iteritems():
        v['L'] = int(); v['k'] = int(); v['M'] = float(0);
        for member in v['members']:
            if type(G.degree(member)) is int:
                v['k'] = v['k'] + (G.degree(member))
            for m in G.edges(member):
                if (m[0] != member and m[0] in v['members']) or (m[1] != member and m[1] in v['members']):
                    v['L'] = v['L'] + 1
    for v in nations.values():
        L = L+ v['k']
    for k,v in nations.iteritems():
        l_c = float(v['L']); k_c = float(v['k'])
        v['M'] = (l_c / L) - (pow((k_c / (2 * L)), 2.0))
    return nations

# %%
nation = calculateModularity(getNations(4))

# %%
def nationModularityTable(nations):
    mt = PrettyTable(['Nation', 'L_c', 'k_c', 'M_c'])
    for k, v in nations.items():
        mt.add_row([k, v['L'], v['k'], "%.5f" % v['M']])
    return mt

# %%
nation = calculateModularity(getNations(10))
print nationModularityTable(nation),'\n'

# %% [markdown]
#  - Retrieve the communities using the Louvain algorithm, and print the corresponding network.

# %%
plt.figure(figsize=(10,10))
partition = community.best_partition(U)
size = float(len(set(partition.values())))
pos = nx.spring_layout(U)
count = 0.
for com in set(partition.values()) :
    count = count + 1.
    list_nodes = [nodes for nodes in partition.keys() if partition[nodes] == com]
    nx.draw_networkx_nodes(U, pos, list_nodes, node_size = 20, node_color = str(count / size))
nx.draw_networkx_edges(U, pos, alpha=0.5)
plt.axis('off')
plt.show()

# %% [markdown]
#  - Calculate the confusion matrix.

# %%
def calculateConfusionMatrix(U):
    partition = community.best_partition(U)
    nations = getNations(30)
    modularity = community.modularity(partition, U)
    noCommunities = max(partition.values())
    D = np.zeros((len(nations), noCommunities))
    for i in range(len(nations)):
        for j in range(noCommunities):
            for v in partition:
                if partition[v] == j:
                    if v in nations.values()[i]['members']:
                        D[i,j] += 1
    return D, modularity, noCommunities

# %%
D, modularity, noCom = calculateConfusionMatrix(U)

# %%
print "Confusion matrix:\n", D

# %% [markdown]
#  - Calculate the distribution of the diagonal elements

# %%
def confusionMatrixDist(D):
    diag = [D[i,j] for i in range(D.shape[0]) for j in range(D.shape[1]) if i == j]
    a, b = np.histogram(diag)

    plt.figure(1)
    plt.plot(b[:-1], a)
    plt.yticks(range(int(max(a))+1))
    plt.title("Distribution of the diagonal elements")
    plt.show()

# %%
confusionMatrixDist(D)
